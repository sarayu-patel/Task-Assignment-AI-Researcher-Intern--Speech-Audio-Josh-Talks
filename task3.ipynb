# %% [markdown]
# <a href="https://colab.research.google.com/github/sarayu-patel/Task-Assignment-AI-Researcher-Intern--Speech-Audio-Josh-Talks/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import requests
import pandas as pd
from pydub import AudioSegment
from io import BytesIO, StringIO
from tqdm.auto import tqdm

# --- Helper Functions (Modified for clarity) ---

def load_data_from_sheet_url(url):
    """Loads a pandas DataFrame from a Google Sheet share URL."""
    print(f"Attempting to load data from: {url}")
    try:
        # Modify the Google Sheet URL to create a direct CSV download link
        file_id = url.split('/d/')[1].split('/')[0]
        gid = url.split('#gid=')[1] if '#gid=' in url else '0'
        download_url = f'https://docs.google.com/spreadsheets/d/{file_id}/export?format=csv&gid={gid}'

        response = requests.get(download_url)
        response.raise_for_status()

        data = StringIO(response.text)
        df = pd.read_csv(data)
        print("Data loaded successfully from Google Sheet.")
        return df
    except Exception as e:
        print(f"Error loading data from URL: {e}")
        return None

def download_audio_from_url(url):
    """Downloads an audio file from a URL and returns it as a pydub AudioSegment."""
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        audio_file = BytesIO(response.content)
        return AudioSegment.from_file(audio_file)
    except Exception as e:
        print(f"Failed to download or process audio from {url}. Error: {e}")
        return None

def download_transcription_json(url):
    """Downloads and parses a transcription JSON file from a URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Failed to download or parse JSON from {url}. Error: {e}")
        return None


# --- Corrected Question 3 Pipeline ---

def question_3_pipeline_corrected(data_url):
    """
    Correctly analyzes segments, detects disfluencies, clips the specific
    audio for that segment, and creates a structured CSV.
    """
    print("\n--- Starting Corrected Question 3 Pipeline: Disfluency Clipping ---\n")

    # 1. Load the main dataset
    print("Step 1: Loading main dataset...")
    df = load_data_from_sheet_url(data_url)
    if df is None or df.empty:
        print("Failed to load data. Aborting pipeline.")
        return

    # Using a small sample for demonstration purposes
    df_sample = df.head(10)
    print(f"Processing a sample of {len(df_sample)} recordings for this demonstration.")

    # 2. Define disfluency patterns
    # FIX: Corrected the regex pattern to avoid the "cannot refer to an open group" error.
    # We now use a non-capturing group (?:...) for the list of filler words.
    filler_words = r'\b(?:मतलब|जैसे|वो|तो|यू नो|बेसिकली)\b'
    # The pattern for repetitions is self-contained and correct.
    repetitions = r'\b(\w+)\s+\1\b'
    # Combine them with a simple OR. No outer capturing group is needed, which resolves the error.
    disfluency_pattern = f"{filler_words}|{repetitions}"
    print(f"Using disfluency pattern: Looking for filler words or repeated words.")

    # 3. Process each recording
    output_data = []
    processed_audio_cache = {} # Cache to avoid re-downloading the same large audio file
    output_clips_dir = "disfluency_clips"
    os.makedirs(output_clips_dir, exist_ok=True)

    print("\nStep 2: Analyzing segments and clipping audio...")
    for index, row in tqdm(df_sample.iterrows(), total=df_sample.shape[0], desc="Processing Recordings"):
        recording_id = row.get('recording_id', f'rec_{index}')
        audio_url = row.get('rec_url_gcp')
        transcription_url = row.get('transcription_url_gcp')

        if not all([audio_url, transcription_url]):
            continue

        # Download the transcription JSON containing segment timestamps
        segments = download_transcription_json(transcription_url)
        if not segments:
            continue

        # Analyze each segment within the recording
        for i, segment in enumerate(segments):
            text = segment.get('text', '')
            start_time = segment.get('start')
            end_time = segment.get('end')

            # Check if segment contains a disfluency and has valid timestamps
            if re.search(disfluency_pattern, text, re.IGNORECASE) and start_time is not None and end_time is not None:

                # Download the full audio only if we haven't already processed this recording
                if recording_id not in processed_audio_cache:
                    print(f"\nDownloading full audio for {recording_id}...")
                    full_audio = download_audio_from_url(audio_url)
                    if not full_audio:
                        break # Move to the next recording if audio download fails
                    processed_audio_cache[recording_id] = full_audio

                full_audio = processed_audio_cache[recording_id]

                # Clip the audio segment using pydub (requires milliseconds)
                start_ms = int(start_time * 1000)
                end_ms = int(end_time * 1000)
                clipped_segment = full_audio[start_ms:end_ms]

                # Save the clipped segment to a unique file
                clip_filename = f"{recording_id}_segment_{i}_{start_time:.2f}s_to_{end_time:.2f}s.wav"
                clip_filepath = os.path.join(output_clips_dir, clip_filename)
                clipped_segment.export(clip_filepath, format="wav")

                # Record the result
                output_data.append({
                    "recording_id": recording_id,
                    "disfluency_text": text,
                    "clipped_audio_path": clip_filepath
                })
                tqdm.write(f"  -> Detected disfluency in segment {i}. Saved clip: {clip_filepath}")

    # 4. Create the structured output CSV
    print("\nStep 3: Creating structured output sheet...")
    if not output_data:
        print("No disfluencies were detected in the sample. The output CSV will be empty.")
        # Create an empty CSV with the correct headers
        output_df = pd.DataFrame(columns=["recording_id", "disfluency_text", "clipped_audio_path"])
    else:
        output_df = pd.DataFrame(output_data)

    output_df.to_csv("disfluency_dataset.csv", index=False)
    print("Output dataset saved to 'disfluency_dataset.csv':")
    print(output_df)


if __name__ == '__main__':
    # URL to the Google Sheet containing the dataset links
    HINDI_ASR_DATA_URL = "https://docs.google.com/spreadsheets/d/1bujiO2NgtHlgqPlNvYAQf5_7ZcXARlIfNX5HNb9f8cI/edit#gid=1786138861"

    # Run the corrected pipeline
    question_3_pipeline_corrected(HINDI_ASR_DATA_URL)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# --- Starting Corrected Question 3 Pipeline: Disfluency Clipping ---
#
# Step 1: Loading main dataset...
# Attempting to load data from: https://docs.google.com/spreadsheets/d/1bujiO2NgtHlgqPlNvYAQf5_7ZcXARlIfNX5HNb9f8cI/edit#gid=1786138861
# Data loaded successfully from Google Sheet.
# Processing a sample of 10 recordings for this demonstration.
# Using disfluency pattern: Looking for filler words or repeated words.
#
# Step 2: Analyzing segments and clipping audio...
# Processing Recordings:   0%|          | 0/10 [00:00<?, ?it/s]
# Downloading full audio for 825780...
#   -> Detected disfluency in segment 0. Saved clip: disfluency_clips/825780_segment_0_0.11s_to_14.42s.wav
#   -> Detected disfluency in segment 1. Saved clip: disfluency_clips/825780_segment_1_14.42s_to_29.03s.wav
#   -> Detected disfluency in segment 4. Saved clip: disfluency_clips/825780_segment_4_52.70s_to_66.83s.wav
#   -> Detected disfluency in segment 6. Saved clip: disfluency_clips/825780_segment_6_89.06s_to_103.19s.wav
#   -> Detected disfluency in segment 7. Saved clip: disfluency_clips/825780_segment_7_103.19s_to_117.29s.wav
#   -> Detected disfluency in segment 9. Saved clip: disfluency_clips/825780_segment_9_130.25s_to_144.83s.wav
#   -> Detected disfluency in segment 10. Saved clip: disfluency_clips/825780_segment_10_146.18s_to_158.21s.wav
#   -> Detected disfluency in segment 13. Saved clip: disfluency_clips/825780_segment_13_178.34s_to_190.85s.wav
#   -> Detected disfluency in segment 16. Saved clip: disfluency_clips/825780_segment_16_224.42s_to_229.73s.wav
#   -> Detected disfluency in segment 19. Saved clip: disfluency_clips/825780_segment_19_257.66s_to_264.08s.wav
#   -> Detected disfluency in segment 23. Saved clip: disfluency_clips/825780_segment_23_373.55s_to_384.47s.wav
#
# Downloading full audio for 825727...
#   -> Detected disfluency in segment 9. Saved clip: disfluency_clips/825727_segment_9_67.19s_to_74.48s.wav
#   -> Detected disfluency in segment 10. Saved clip: disfluency_clips/825727_segment_10_78.92s_to_90.08s.wav
#   -> Detected disfluency in segment 17. Saved clip: disfluency_clips/825727_segment_17_143.15s_to_148.10s.wav
#   -> Detected disfluency in segment 19. Saved clip: disfluency_clips/825727_segment_19_155.42s_to_162.05s.wav
#   -> Detected disfluency in segment 21. Saved clip: disfluency_clips/825727_segment_21_176.57s_to_191.15s.wav
#   -> Detected disfluency in segment 25. Saved clip: disfluency_clips/825727_segment_25_231.20s_to_246.08s.wav
#   -> Detected disfluency in segment 26. Saved clip: disfluency_clips/825727_segment_26_246.38s_to_260.12s.wav
#   -> Detected disfluency in segment 27. Saved clip: disfluency_clips/825727_segment_27_262.97s_to_276.47s.wav
#   -> Detected disfluency in segment 28. Saved clip: disfluency_clips/825727_segment_28_276.47s_to_291.35s.wav
#   -> Detected disfluency in segment 29. Saved clip: disfluency_clips/825727_segment_29_291.44s_to_306.41s.wav
#   -> Detected disfluency in segment 30. Saved clip: disfluency_clips/825727_segment_30_306.44s_to_314.36s.wav
#   -> Detected disfluency in segment 31. Saved clip: disfluency_clips/825727_segment_31_314.42s_to_327.53s.wav
#   -> Detected disfluency in segment 34. Saved clip: disfluency_clips/825727_segment_34_355.88s_to_369.77s.wav
#   -> Detected disfluency in segment 35. Saved clip: disfluency_clips/825727_segment_35_370.01s_to_375.44s.wav
#
# Downloading full audio for 988596...
#   -> Detected disfluency in segment 13. Saved clip: disfluency_clips/988596_segment_13_202.61s_to_205.25s.wav
#   -> Detected disfluency in segment 16. Saved clip: disfluency_clips/988596_segment_16_224.00s_to_237.92s.wav
#   -> Detected disfluency in segment 18. Saved clip: disfluency_clips/988596_segment_18_253.34s_to_267.74s.wav
#   -> Detected disfluency in segment 19. Saved clip: disfluency_clips/988596_segment_19_267.80s_to_282.53s.wav
#   -> Detected disfluency in segment 20. Saved clip: disfluency_clips/988596_segment_20_282.74s_to_296.00s.wav
#   -> Detected disfluency in segment 21. Saved clip: disfluency_clips/988596_segment_21_296.06s_to_310.64s.wav
#   -> Detected disfluency in segment 22. Saved clip: disfluency_clips/988596_segment_22_310.94s_to_324.98s.wav
#   -> Detected disfluency in segment 23. Saved clip: disfluency_clips/988596_segment_23_325.07s_to_337.13s.wav
#   -> Detected disfluency in segment 24. Saved clip: disfluency_clips/988596_segment_24_337.22s_to_351.44s.wav
#
# Downloading full audio for 990175...
#   -> Detected disfluency in segment 1. Saved clip: disfluency_clips/990175_segment_1_13.64s_to_22.85s.wav
#   -> Detected disfluency in segment 3. Saved clip: disfluency_clips/990175_segment_3_36.20s_to_50.84s.wav
#   -> Detected disfluency in segment 4. Saved clip: disfluency_clips/990175_segment_4_50.84s_to_61.37s.wav
#   -> Detected disfluency in segment 5. Saved clip: disfluency_clips/990175_segment_5_61.43s_to_74.93s.wav
#   -> Detected disfluency in segment 6. Saved clip: disfluency_clips/990175_segment_6_74.93s_to_89.42s.wav
#   -> Detected disfluency in segment 9. Saved clip: disfluency_clips/990175_segment_9_113.27s_to_127.91s.wav
#   -> Detected disfluency in segment 10. Saved clip: disfluency_clips/990175_segment_10_127.94s_to_142.37s.wav
#   -> Detected disfluency in segment 11. Saved clip: disfluency_clips/990175_segment_11_142.37s_to_157.25s.wav
#   -> Detected disfluency in segment 12. Saved clip: disfluency_clips/990175_segment_12_157.25s_to_171.32s.wav
#   -> Detected disfluency in segment 14. Saved clip: disfluency_clips/990175_segment_14_188.21s_to_199.46s.wav
#   -> Detected disfluency in segment 16. Saved clip: disfluency_clips/990175_segment_16_210.17s_to_213.23s.wav
#   -> Detected disfluency in segment 17. Saved clip: disfluency_clips/990175_segment_17_215.36s_to_221.36s.wav
#   -> Detected disfluency in segment 21. Saved clip: disfluency_clips/990175_segment_21_380.63s_to_388.46s.wav
#
# Downloading full audio for 526266...
#   -> Detected disfluency in segment 38. Saved clip: disfluency_clips/526266_segment_38_460.72s_to_465.37s.wav
#
# Downloading full audio for 520199...
#   -> Detected disfluency in segment 13. Saved clip: disfluency_clips/520199_segment_13_133.60s_to_138.25s.wav
#   -> Detected disfluency in segment 18. Saved clip: disfluency_clips/520199_segment_18_189.52s_to_197.26s.wav
#   -> Detected disfluency in segment 27. Saved clip: disfluency_clips/520199_segment_27_291.97s_to_295.21s.wav
#   -> Detected disfluency in segment 28. Saved clip: disfluency_clips/520199_segment_28_297.64s_to_311.20s.wav
#   -> Detected disfluency in segment 29. Saved clip: disfluency_clips/520199_segment_29_313.78s_to_325.84s.wav
#   -> Detected disfluency in segment 30. Saved clip: disfluency_clips/520199_segment_30_328.00s_to_330.40s.wav
#   -> Detected disfluency in segment 40. Saved clip: disfluency_clips/520199_segment_40_410.86s_to_421.39s.wav
#
# Downloading full audio for 542785...
#   -> Detected disfluency in segment 7. Saved clip: disfluency_clips/542785_segment_7_77.98s_to_92.29s.wav
#   -> Detected disfluency in segment 12. Saved clip: disfluency_clips/542785_segment_12_124.06s_to_132.88s.wav
#   -> Detected disfluency in segment 15. Saved clip: disfluency_clips/542785_segment_15_158.47s_to_161.11s.wav
#   -> Detected disfluency in segment 22. Saved clip: disfluency_clips/542785_segment_22_226.42s_to_231.01s.wav
#   -> Detected disfluency in segment 28. Saved clip: disfluency_clips/542785_segment_28_274.66s_to_289.00s.wav
#   -> Detected disfluency in segment 34. Saved clip: disfluency_clips/542785_segment_34_336.67s_to_347.11s.wav
#   -> Detected disfluency in segment 41. Saved clip: disfluency_clips/542785_segment_41_416.14s_to_426.79s.wav
#   -> Detected disfluency in segment 42. Saved clip: disfluency_clips/542785_segment_42_429.40s_to_444.28s.wav
#   -> Detected disfluency in segment 56. Saved clip: disfluency_clips/542785_segment_56_539.11s_to_553.30s.wav
#
# Downloading full audio for 494019...
#   -> Detected disfluency in segment 3. Saved clip: disfluency_clips/494019_segment_3_32.74s_to_38.86s.wav
#   -> Detected disfluency in segment 12. Saved clip: disfluency_clips/494019_segment_12_151.15s_to_165.79s.wav
#   -> Detected disfluency in segment 37. Saved clip: disfluency_clips/494019_segment_37_396.01s_to_409.63s.wav
#   -> Detected disfluency in segment 46. Saved clip: disfluency_clips/494019_segment_46_520.12s_to_529.87s.wav
#
# Downloading full audio for 523045...
#   -> Detected disfluency in segment 8. Saved clip: disfluency_clips/523045_segment_8_93.49s_to_104.23s.wav
#   -> Detected disfluency in segment 10. Saved clip: disfluency_clips/523045_segment_10_122.74s_to_134.89s.wav
#   -> Detected disfluency in segment 16. Saved clip: disfluency_clips/523045_segment_16_201.91s_to_216.31s.wav
#   -> Detected disfluency in segment 31. Saved clip: disfluency_clips/523045_segment_31_390.13s_to_396.70s.wav
#   -> Detected disfluency in segment 33. Saved clip: disfluency_clips/523045_segment_33_406.18s_to_418.60s.wav
#   -> Detected disfluency in segment 37. Saved clip: disfluency_clips/523045_segment_37_457.45s_to_466.51s.wav
#
# Downloading full audio for 522951...
#   -> Detected disfluency in segment 1. Saved clip: disfluency_clips/522951_segment_1_13.09s_to_20.56s.wav
#   -> Detected disfluency in segment 7. Saved clip: disfluency_clips/522951_segment_7_77.20s_to_88.57s.wav
#   -> Detected disfluency in segment 17. Saved clip: disfluency_clips/522951_segment_17_224.92s_to_231.73s.wav
#   -> Detected disfluency in segment 19. Saved clip: disfluency_clips/522951_segment_19_269.44s_to_274.69s.wav
#   -> Detected disfluency in segment 20. Saved clip: disfluency_clips/522951_segment_20_278.53s_to_286.27s.wav
#   -> Detected disfluency in segment 21. Saved clip: disfluency_clips/522951_segment_21_289.78s_to_295.69s.wav
#   -> Detected disfluency in segment 22. Saved clip: disfluency_clips/522951_segment_22_310.84s_to_317.17s.wav
#   -> Detected disfluency in segment 24. Saved clip: disfluency_clips/522951_segment_24_357.34s_to_371.44s.wav
#   -> Detected disfluency in segment 25. Saved clip: disfluency_clips/522951_segment_25_397.60s_to_406.15s.wav
#   -> Detected disfluency in segment 34. Saved clip: disfluency_clips/522951_segment_34_502.69s_to_515.14s.wav
#   -> Detected disfluency in segment 35. Saved clip: disfluency_clips/522951_segment_35_515.14s_to_529.57s.wav
#   -> Detected disfluency in segment 36. Saved clip: disfluency_clips/522951_segment_36_530.53s_to_537.37s.wav
#   -> Detected disfluency in segment 37. Saved clip: disfluency_clips/522951_segment_37_539.44s_to_544.15s.wav
#
# Step 3: Creating structured output sheet...
# Output dataset saved to 'disfluency_dataset.csv':
#     recording_id                                    disfluency_text  \
# 0         825780  अब काफी अच्छा होता है क्योंकि उनकी जनसंख्या बह...
# 1         825780  अनुभव करके कुछ लिखना था तो वह तो बिना देखिए नह...
# 2         825780  हां तो फिर वहां जो दिन भर तो दिन में तो खोजने ...
# 3         825780  डर लगता है लेकिन बहुत सारे थे तो पता सब अपना अ...
# 4         825780  ऐसा ही बात था तो पता है रात को मतलब जैसे छः सा...
# ..           ...                                                ...
# 82        522951  हुंह हुंह कॉमेडी अभी अच्छी नहीं आती है मतलब और...
# 83        522951  मैं अब मैं तो अपने मूड के ऊपर सुनता हूं गाने ।...
# 84        522951  अभी दस बारा साल पुराने है ऐसे गाने भी सुनता हू...
# 85        522951  वो अलगअलग मतलब सुनता हूँ मैं अपने मूड के ऊपर र...
# 86        522951  नए नए गाने इतने मतलब अच्छे नहीं होता है जो बार...
#
#                                    clipped_audio_path
# 0   disfluency_clips/825780_segment_0_0.11s_to_14....
# 1   disfluency_clips/825780_segment_1_14.42s_to_29...
# 2   disfluency_clips/825780_segment_4_52.70s_to_66...
# 3   disfluency_clips/825780_segment_6_89.06s_to_10...
# 4   disfluency_clips/825780_segment_7_103.19s_to_1...
# ..                                                ...
# 82  disfluency_clips/522951_segment_25_397.60s_to_...
# 83  disfluency_clips/522951_segment_34_502.69s_to_...
# 84  disfluency_clips/522951_segment_35_515.14s_to_...
# 85  disfluency_clips/522951_segment_36_530.53s_to_...
# 86  disfluency_clips/522951_segment_37_539.44s_to_...
#
# [87 rows x 3 columns]
